# %% [markdown]
# ## Creating a Resume answering agent
# In this project, I will create an AI agent to answer questions related to my professional resume
#
# There is a folder called "me", inside this folder, there is a PDF file containing a copy of my LinkedIn profile
#
# There is also a text file named "summary" that contains details about my professional profile.
#
# I will start by importing the necessary libraries.
#
# pypdf is a library to handle PDF files

# %%
from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader

# %% [markdown]
# import gradio as gr loads Gradio, a Python library that lets you build web-based user interfaces—usually for
#
# machine learning models, APIs, or any Python function—with just a few lines of code.

# %%
import gradio as gr
